# %% [markdown]
# ## 1. Carga del dataset

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Cargar el dataset
path = "../data/raw/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv"
df_trafico = pd.read_csv(path)
# Estilo para los graficos
plt.style.use("seaborn-v0_8")

# Se enlistan los nombres de todas las columnas por posibles errorres gramaticales
df_trafico.columns.to_list()
# Out:
# ['Flow ID',
#  ' Source IP',
#  ' Source Port',
#  ' Destination IP',
#  ' Destination Port',
#  ' Protocol',
#  ' Timestamp',
#  ' Flow Duration',
#  ' Total Fwd Packets',
#  ' Total Backward Packets',
#  'Total Length of Fwd Packets',
#  ' Total Length of Bwd Packets',
#  ' Fwd Packet Length Max',
#  ' Fwd Packet Length Min',
#  ' Fwd Packet Length Mean',
#  ' Fwd Packet Length Std',
#  'Bwd Packet Length Max',
#  ' Bwd Packet Length Min',
#  ' Bwd Packet Length Mean',
#  ' Bwd Packet Length Std',
#  'Flow Bytes/s',
#  ' Flow Packets/s',
#  ' Flow IAT Mean',
#  ' Flow IAT Std',
#  ' Flow IAT Max',
#  ' Flow IAT Min',
#  'Fwd IAT Total',
#  ' Fwd IAT Mean',
#  ' Fwd IAT Std',
#  ' Fwd IAT Max',
#  ' Fwd IAT Min',
#  'Bwd IAT Total',
#  ' Bwd IAT Mean',
#  ' Bwd IAT Std',
#  ' Bwd IAT Max',
#  ' Bwd IAT Min',
#  'Fwd PSH Flags',
#  ' Bwd PSH Flags',
#  ' Fwd URG Flags',
#  ' Bwd URG Flags',
#  ' Fwd Header Length',
#  ' Bwd Header Length',
#  'Fwd Packets/s',
#  ' Bwd Packets/s',
#  ' Min Packet Length',
#  ' Max Packet Length',
#  ' Packet Length Mean',
#  ' Packet Length Std',
#  ' Packet Length Variance',
#  'FIN Flag Count',
#  ' SYN Flag Count',
#  ' RST Flag Count',
#  ' PSH Flag Count',
#  ' ACK Flag Count',
#  ' URG Flag Count',
#  ' CWE Flag Count',
#  ' ECE Flag Count',
#  ' Down/Up Ratio',
#  ' Average Packet Size',
#  ' Avg Fwd Segment Size',
#  ' Avg Bwd Segment Size',
#  ' Fwd Header Length.1',
#  'Fwd Avg Bytes/Bulk',
#  ' Fwd Avg Packets/Bulk',
#  ' Fwd Avg Bulk Rate',
#  ' Bwd Avg Bytes/Bulk',
#  ' Bwd Avg Packets/Bulk',
#  'Bwd Avg Bulk Rate',
#  'Subflow Fwd Packets',
#  ' Subflow Fwd Bytes',
#  ' Subflow Bwd Packets',
#  ' Subflow Bwd Bytes',
#  'Init_Win_bytes_forward',
#  ' Init_Win_bytes_backward',
#  ' act_data_pkt_fwd',
#  ' min_seg_size_forward',
#  'Active Mean',
#  ' Active Std',
#  ' Active Max',
#  ' Active Min',
#  'Idle Mean',
#  ' Idle Std',
#  ' Idle Max',
#  ' Idle Min',
#  ' Label']

# %% [markdown]
# ## 2. Normalización de columnas

# %%
def limpiar_col(col):
    #Convertir a string
    col = str(col)

    #Quitar espacios al inicio y final
    col = col.strip()

    #Reemplazar '.' por '_' (ejemplo de ello el "Lenght.1")
    col = col.replace('.', '_')

    #Reemplazar cualquier secuecnia de espacios por '_'
    col = re.sub(r'\s+','_', col)

    #Convertir a minúsculas
    col = col.lower()

    #Colapsar múltiples underscores
    while "__" in col:
        col = col.replace("__"," _")
    return col

# Aplicar limpieza profesional
df_trafico.columns = [limpiar_col(c) for c in df_trafico.columns]

df_trafico.columns.to_list()
# Out:
# ['flow_id',
#  'source_ip',
#  'source_port',
#  'destination_ip',
#  'destination_port',
#  'protocol',
#  'timestamp',
#  'flow_duration',
#  'total_fwd_packets',
#  'total_backward_packets',
#  'total_length_of_fwd_packets',
#  'total_length_of_bwd_packets',
#  'fwd_packet_length_max',
#  'fwd_packet_length_min',
#  'fwd_packet_length_mean',
#  'fwd_packet_length_std',
#  'bwd_packet_length_max',
#  'bwd_packet_length_min',
#  'bwd_packet_length_mean',
#  'bwd_packet_length_std',
#  'flow_bytes/s',
#  'flow_packets/s',
#  'flow_iat_mean',
#  'flow_iat_std',
#  'flow_iat_max',
#  'flow_iat_min',
#  'fwd_iat_total',
#  'fwd_iat_mean',
#  'fwd_iat_std',
#  'fwd_iat_max',
#  'fwd_iat_min',
#  'bwd_iat_total',
#  'bwd_iat_mean',
#  'bwd_iat_std',
#  'bwd_iat_max',
#  'bwd_iat_min',
#  'fwd_psh_flags',
#  'bwd_psh_flags',
#  'fwd_urg_flags',
#  'bwd_urg_flags',
#  'fwd_header_length',
#  'bwd_header_length',
#  'fwd_packets/s',
#  'bwd_packets/s',
#  'min_packet_length',
#  'max_packet_length',
#  'packet_length_mean',
#  'packet_length_std',
#  'packet_length_variance',
#  'fin_flag_count',
#  'syn_flag_count',
#  'rst_flag_count',
#  'psh_flag_count',
#  'ack_flag_count',
#  'urg_flag_count',
#  'cwe_flag_count',
#  'ece_flag_count',
#  'down/up_ratio',
#  'average_packet_size',
#  'avg_fwd_segment_size',
#  'avg_bwd_segment_size',
#  'fwd_header_length_1',
#  'fwd_avg_bytes/bulk',
#  'fwd_avg_packets/bulk',
#  'fwd_avg_bulk_rate',
#  'bwd_avg_bytes/bulk',
#  'bwd_avg_packets/bulk',
#  'bwd_avg_bulk_rate',
#  'subflow_fwd_packets',
#  'subflow_fwd_bytes',
#  'subflow_bwd_packets',
#  'subflow_bwd_bytes',
#  'init_win_bytes_forward',
#  'init_win_bytes_backward',
#  'act_data_pkt_fwd',
#  'min_seg_size_forward',
#  'active_mean',
#  'active_std',
#  'active_max',
#  'active_min',
#  'idle_mean',
#  'idle_std',
#  'idle_max',
#  'idle_min',
#  'label']

# %% [markdown]
# ## 3. Conversión de timestamp

# %%
# Convertir timestamp a datetime
df_trafico["timestamp"] = pd.to_datetime(df_trafico["timestamp"], errors = "coerce")
# Se debe observar el cambio de formato en la fecha
df_trafico.head()
# Out:
#                                    flow_id       source_ip  source_port  \
# 0  192.168.10.5-104.16.207.165-54865-443-6  104.16.207.165          443
# 1    192.168.10.5-104.16.28.216-55054-80-6   104.16.28.216           80
# 2    192.168.10.5-104.16.28.216-55055-80-6   104.16.28.216           80
# 3  192.168.10.16-104.17.241.25-46236-443-6   104.17.241.25          443
# 4  192.168.10.5-104.19.196.102-54863-443-6  104.19.196.102          443
#
#   destination_ip  destination_port  protocol           timestamp  \
# 0   192.168.10.5             54865         6 2017-07-07 03:30:00
# 1   192.168.10.5             55054         6 2017-07-07 03:30:00
# 2   192.168.10.5             55055         6 2017-07-07 03:30:00
# 3  192.168.10.16             46236         6 2017-07-07 03:30:00
# 4   192.168.10.5             54863         6 2017-07-07 03:30:00
#
#    flow_duration  total_fwd_packets  total_backward_packets  ...  \
# 0              3                  2                       0  ...
# 1            109                  1                       1  ...
# 2             52                  1                       1  ...
# 3             34                  1                       1  ...
# 4              3                  2                       0  ...
#
#    min_seg_size_forward  active_mean  active_std  active_max  active_min  \
# 0                    20          0.0         0.0           0           0
# 1                    20          0.0         0.0           0           0
# 2                    20          0.0         0.0           0           0
# 3                    20          0.0         0.0           0           0
# 4                    20          0.0         0.0           0           0
#
#    idle_mean  idle_std  idle_max  idle_min   label
# 0        0.0       0.0         0         0  BENIGN
# 1        0.0       0.0         0         0  BENIGN
# 2        0.0       0.0         0         0  BENIGN
# 3        0.0       0.0         0         0  BENIGN
# 4        0.0       0.0         0         0  BENIGN
#
# [5 rows x 85 columns]

# %% [markdown]
# ## 4. Ordenamiento

# %%
# Eliminar filas con timestamp inválido
df_trafico = df_trafico.dropna(subset=["timestamp"])

# %%
# Ordenar cronologicamente
df_trafico = df_trafico.sort_values("timestamp").reset_index(drop=True)

# %% [markdown]
# ## 5. Creación de métricas

# %% [markdown]
# ### 5.1. Métricas por flujo

# %%
# Total de paquetes por flujo
df_trafico["total_pkts"] = df_trafico["total_fwd_packets"] + df_trafico["total_backward_packets"]
df_trafico[["timestamp","total_fwd_packets","total_backward_packets", "total_pkts"]].head()
# Out:
#             timestamp  total_fwd_packets  total_backward_packets  total_pkts
# 0 2017-07-07 03:30:00                  2                       0           2
# 1 2017-07-07 03:30:00                  4                       2           6
# 2 2017-07-07 03:30:00                  4                       2           6
# 3 2017-07-07 03:30:00                  2                       2           4
# 4 2017-07-07 03:30:00                  2                       2           4

# %%
# Volumen de bytes por flujo (menos util que total_pkts)
df_trafico["total_bytes"] = df_trafico["total_length_of_fwd_packets"] + df_trafico["total_length_of_bwd_packets"]
df_trafico[["timestamp","total_length_of_fwd_packets","total_length_of_bwd_packets", "total_bytes"]].head()
# Out:
#             timestamp  total_length_of_fwd_packets  \
# 0 2017-07-07 03:30:00                           12
# 1 2017-07-07 03:30:00                          152
# 2 2017-07-07 03:30:00                          176
# 3 2017-07-07 03:30:00                           82
# 4 2017-07-07 03:30:00                          124
#
#    total_length_of_bwd_packets  total_bytes
# 0                            0           12
# 1                          190          342
# 2                          344          520
# 3                          114          196
# 4                          248          372

# %% [markdown]
# ### 5.2. Métricas derivadas temporales

# %% [markdown]
# *df_trafico["pkts_rate"] = df_trafico["total_pkts"] / 60*
#
# *df_trafico["bytes_rate"] = df_trafico["total_bytes"] / 60*
#
# *df_trafico["pkts_per_flow"] = df_trafico["total_pkts"] / (df_trafico["num_ddos_flow"] + 1e-6)*

# %% [markdown]
# ## 6. Resampleo por minuto

# %%
# Definir indice temporal
df_trafico_ts = df_trafico.set_index("timestamp")

# Re-sampleo a 1 minuto
df_trafico_min = (df_trafico_ts.resample("1min").agg({
    
    # Métricas de volumen agregadas
    "total_pkts":"sum",
    "total_bytes":"sum",

    # Métricas por flujo agregadas como promedio
    "flow_bytes/s":"mean",
    "flow_packets/s":"mean",
    "flow_iat_mean":"mean",
    "active_mean":"mean",
    "idle_mean":"mean",

    # Conteo de flujos DD
    "label":lambda x: (x == "DDoS").sum()
}))

# Renombrar columna de conteo DDoS
df_trafico_min = df_trafico_min.rename(columns={"label":"num_ddos_flows"})

df_trafico_min["pkts_rate"] = df_trafico_min["total_pkts"] / 60
df_trafico_min["bytes_rate"] = df_trafico_min["total_bytes"] / 60
df_trafico_min["pkts_per_flow"] = df_trafico_min["total_pkts"] / (df_trafico_min["num_ddos_flows"] + 1e-6)

df_trafico_min
# Out:
#                      total_pkts  total_bytes  flow_bytes/s  flow_packets/s  \
# timestamp
# 2017-07-07 03:30:00       43583     35186405           inf             inf
# 2017-07-07 03:31:00       27517     15873318           inf             inf
# 2017-07-07 03:32:00        3899      1760887  4.675717e+06    9.102111e+04
# 2017-07-07 03:33:00       16056      6351927  1.380671e+06    4.350707e+04
# 2017-07-07 03:34:00       10606      5452445  1.349385e+06    4.824574e+04
# ...                         ...          ...           ...             ...
# 2017-07-07 04:58:00       15842      7483075  2.055290e+06    4.089908e+04
# 2017-07-07 04:59:00        5093      1506179  1.060551e+06    6.753485e+04
# 2017-07-07 05:00:00       14139      6765110  6.855868e+05    3.488642e+04
# 2017-07-07 05:01:00        1931       251928  1.334574e+06    1.322547e+05
# 2017-07-07 05:02:00         797        75534  1.255699e+06    6.984436e+04
#
#                      flow_iat_mean    active_mean     idle_mean  \
# timestamp
# 2017-07-07 03:30:00   6.884039e+05  118579.151464  3.247528e+06
# 2017-07-07 03:31:00   6.860297e+05   71027.774723  3.335710e+06
# 2017-07-07 03:32:00   6.338513e+05   33379.712885  4.343144e+06
# 2017-07-07 03:33:00   1.073293e+06  129475.865941  4.494442e+06
# 2017-07-07 03:34:00   6.350480e+05   40147.639813  2.939384e+06
# ...                            ...            ...           ...
# 2017-07-07 04:58:00   1.300451e+06  105551.483156  4.482400e+06
# 2017-07-07 04:59:00   6.740141e+05   83376.787542  3.402926e+06
# 2017-07-07 05:00:00   8.379654e+05   57194.198328  2.115612e+06
# 2017-07-07 05:01:00   4.671161e+05   53728.670403  1.266708e+06
# 2017-07-07 05:02:00   1.456743e+05   14818.508388  5.257389e+05
#
#                      num_ddos_flows   pkts_rate     bytes_rate  pkts_per_flow
# timestamp
# 2017-07-07 03:30:00               0  726.383333  586440.083333   4.358300e+10
# 2017-07-07 03:31:00               0  458.616667  264555.300000   2.751700e+10
# 2017-07-07 03:32:00               0   64.983333   29348.116667   3.899000e+09
# 2017-07-07 03:33:00               0  267.600000  105865.450000   1.605600e+10
# 2017-07-07 03:34:00               0  176.766667   90874.083333   1.060600e+10
# ...                             ...         ...            ...            ...
# 2017-07-07 04:58:00               0  264.033333  124717.916667   1.584200e+10
# 2017-07-07 04:59:00               0   84.883333   25102.983333   5.093000e+09
# 2017-07-07 05:00:00               0  235.650000  112751.833333   1.413900e+10
# 2017-07-07 05:01:00               0   32.183333    4198.800000   1.931000e+09
# 2017-07-07 05:02:00               0   13.283333    1258.900000   7.970000e+08
#
# [93 rows x 11 columns]

# %% [markdown]
# ## 7. Asegurar continuidad temporal

# %%
# Rango completo esperado de minutos
expected_index = pd.date_range(
    start=df_trafico_min.index.min(),
    end=df_trafico_min.index.max(),
    freq="1min"
)

# Minutos que faltan
missing = expected_index.difference(df_trafico_min.index)
print("Minutos faltantes:", len(missing))

# Reindexar para incluir todos los minutos y rellenar con 0
df_trafico_min = df_trafico_min.reindex(expected_index)
df_trafico_min = df_trafico_min.fillna(0)

df_trafico_min.index.name = "timestamp"
df_trafico_min.head()
# Out:
# Minutos faltantes: 0
#                      total_pkts  total_bytes  flow_bytes/s  flow_packets/s  \
# timestamp
# 2017-07-07 03:30:00       43583     35186405           inf             inf
# 2017-07-07 03:31:00       27517     15873318           inf             inf
# 2017-07-07 03:32:00        3899      1760887  4.675717e+06    9.102111e+04
# 2017-07-07 03:33:00       16056      6351927  1.380671e+06    4.350707e+04
# 2017-07-07 03:34:00       10606      5452445  1.349385e+06    4.824574e+04
#
#                      flow_iat_mean    active_mean     idle_mean  \
# timestamp
# 2017-07-07 03:30:00   6.884039e+05  118579.151464  3.247528e+06
# 2017-07-07 03:31:00   6.860297e+05   71027.774723  3.335710e+06
# 2017-07-07 03:32:00   6.338513e+05   33379.712885  4.343144e+06
# 2017-07-07 03:33:00   1.073293e+06  129475.865941  4.494442e+06
# 2017-07-07 03:34:00   6.350480e+05   40147.639813  2.939384e+06
#
#                      num_ddos_flows   pkts_rate     bytes_rate  pkts_per_flow
# timestamp
# 2017-07-07 03:30:00               0  726.383333  586440.083333   4.358300e+10
# 2017-07-07 03:31:00               0  458.616667  264555.300000   2.751700e+10
# 2017-07-07 03:32:00               0   64.983333   29348.116667   3.899000e+09
# 2017-07-07 03:33:00               0  267.600000  105865.450000   1.605600e+10
# 2017-07-07 03:34:00               0  176.766667   90874.083333   1.060600e+10

# %% [markdown]
# ## 8. Gráfico de validación

# %%
plt.figure(figsize=(18,10))
plt.plot(df_trafico_min.index, df_trafico_min["total_pkts"])
plt.title("Serie temporal: total_pkts por minuto")
plt.xlabel("Tiempo (HH:MM)", fontsize=12)
plt.ylabel("Volumen de paquetes por minuto")

# Formato para visualizar solo la hora en el eje x
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

# Formato para fecha + hora completa
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))

plt.grid(True)
plt.tight_layout()

# Exportar el gráfico
ruta = "../results/01_paquetes_por_minuto.png"
plt.savefig(ruta, dpi = 300, bbox_inches = 'tight',facecolor = 'white',edgecolor = 'none')

print("Gráfico exportado exitosamente a: ", ruta)

plt.show()
# Out:
# Gráfico exportado exitosamente a:  ../results/01_paquetes_por_minuto.png

# %% [markdown]
# ## 9. Exportar la serie temporal a un csv

# %%
# Exportar la serie temporal
path_salida = "../data/processed/serie_temporal.csv"
df_trafico_min.to_csv(path_salida)
print("Serie temporal exportada correctamente a: ", path_salida)

# Exportar dataset limpio y nombre de columnas normalizadas
path_salida2 = "../data/processed/dataset_limpio.csv"
df_trafico_ts.to_csv(path_salida2, index=True)
print("Dataset limpio exportado correctamente a: ", path_salida2)
# Out:
# Serie temporal exportada correctamente a:  ../data/processed/serie_temporal.csv
# Dataset limpio exportado correctamente a:  ../data/processed/dataset_limpio.csv
